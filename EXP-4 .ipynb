# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaluvai1203/CSA6102---Lab-/blob/main/EXP-4%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket
domain = input("Enter the domain name (e.g., google.com): ")

try:
    ip_address = socket.gethostbyname(domain)

    print("\nDNS Lookup Result")
    print("-" * 30)
    print("Domain Name :", domain)
    print("IP Address  :", ip_address)

except socket.gaierror:
    print("\nError: Unable to resolve the domain name.")
# Out:
# Enter the domain name (e.g., google.com): google.com
#
# DNS Lookup Result
# ------------------------------
# Domain Name : google.com
# IP Address  : 74.125.142.138
