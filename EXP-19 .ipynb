# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaluvai1203/CSA6102---Lab-/blob/main/EXP-19%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install psutil -q

import os, shutil, hashlib, json, time, random

import psutil

print("Setup complete.")
# Out:
# Setup complete.

# %%
import os
import psutil

def capture_volatile_evidence():
    processes = [p.info for p in psutil.process_iter(['pid', 'name'])]

    return {
        "running_process_count": len(processes),
        "sample_processes": processes[:5]
    }

def capture_nonvolatile_evidence(folder):
    files = sorted(os.listdir(folder))

    return {
        "disk_files": files,
        "file_count": len(files)
    }

volatile_snapshot = capture_volatile_evidence()
nonvolatile_snapshot = capture_nonvolatile_evidence(evidence_dir)

print("Volatile evidence -> Running Processes:",
      volatile_snapshot["running_process_count"])

print("Sample Processes:")
for process in volatile_snapshot["sample_processes"]:
    print(process)

print("\nNon-Volatile Evidence:")
print(nonvolatile_snapshot)
# Out:
# Volatile evidence -> Running Processes: 15
# Sample Processes:
# {'pid': 1, 'name': 'docker-init'}
# {'pid': 7, 'name': 'node'}
# {'pid': 9, 'name': 'oom_monitor.sh'}
# {'pid': 11, 'name': 'run.sh'}
# {'pid': 12, 'name': 'kernel_manager_proxy'}
#
# Non-Volatile Evidence:
# {'disk_files': ['browser_history.txt', 'chat_message.txt', 'email_log.txt', 'system_log.txt'], 'file_count': 4}
